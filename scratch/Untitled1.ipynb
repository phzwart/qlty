# %%
from qlty import qlty2DLarge
import torch
data = torch.rand((2,1,5,5))
labels = torch.ones((2,5,5))
qobj = qlty2DLarge.LargeNCYXQuilt('mycache', N=1,Y=3,X=3, window=(3,3), step=(1,1), border=(1,1) )
dd,ll = qobj.unstitch_and_clean_sparse_data_pair(data, labels, missing_label=-1)

# %%
print(dd.shape,ll.shape)
# Out:
# torch.Size([1, 1, 3, 3]) torch.Size([1, 3, 3])
